# %% [markdown]
# ### Questions
# * What is the `w` vector? It's a weight vector...like a $\beta$ vector
#     * the 2 lines around the center line are made up of b+wx = 1 and b+2x=-1
#     * these are the decision boundaries

# %% [markdown]
# ### Objectives
# YWBAT
# * compare and contrast the various methods for SVMs
# * implement SVMs using sklearn
# * use model analysis to tailor SVM

# %% [markdown]
# ### Outline
# - Introduce dataset
# - Go through various svm models and their use case
# - Tweak SVMs to suit the problem

# %% [markdown]
# ### What do SVMs do?
# SVMs (Support Vector Machines) are machine learning models that divide data by using 'support vectors' to create decision boundaries.
#
# The sensitivity (or lack thereof) of your boundaries depends on you.
#
# Low Sensitivity boundaries are often wide
# High Sensitivity boundaries are very narrow

# %% [markdown]
# ### When? Why?
#
# SVMs are great to use anytime you want decisions to be made by using boundaries.  One example is finding points that are closest to the boundary and then using those points in your training set.  Boundaries are very helpful for classification, but also helpful for finding training points.
#
# Build a model
# - classify new points and evaluate our classification
# - if points weren't classified correctly we took their distance from the mislabeled class boundary
# - add those points to our training set

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_circles,  make_blobs, make_moons
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_groups(x, y):
    plt.figure(figsize=(8, 8))
    plt.grid(linestyle='dashed')
    color_dict = {0: 'g', 1: 'purple'}
    colors = ['g' if l == 0 else 'purple' for l in y]
    plt.scatter(x[:, 0], x[:, 1], c=colors, s=60, alpha=0.5)
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.show()
    

def plot_groups3(x, y):
    plt.figure(figsize=(8, 8))
    plt.grid(linestyle='dashed')
    color_dict = {0: 'g', 1: 'purple', 2: 'yellow'}
    colors = [color_dict[l] for l in y]
    plt.scatter(x[:, 0], x[:, 1], c=colors, alpha=0.5, s=60)
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.show()
    

    
def plot_svm_groups(x, y, clf):
    plt.figure(figsize=(8, 5))
    plt.grid()
    plot_decision_regions(x, y, clf, colors='green,purple,yellow', scatter_kwargs={"s": 100, "alpha": 0.5})
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.title("SVM Decision Boundary")
    plt.show()
    

def print_report(ytrain, ytest, ytrain_pred, ytest_pred):
    report = classification_report(ytrain, ytrain_pred)
    print("Train Scores\n" + "-"*50)
    print(report)
    accuracy = accuracy_score(ytrain, ytrain_pred)
    print(f"Train Accuracy: {accuracy}")
    report = classification_report(ytest, ytest_pred)
    print("Test Scores\n" + "-"*50)
    print(report)
    accuracy = accuracy_score(ytest, ytest_pred)
    print(f"Test Accuracy: {accuracy}")

# %% [markdown]
# ## Linear SVM
# ![](images/svm-linear.png)

# %%
x, y = make_blobs(n_samples=500, n_features=2, centers=2, cluster_std=4.5)

# %%
plot_groups(x, y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y)

# %%
clfl2 = LinearSVC(penalty='l2', C=0.1)
clfl2.fit(xtrain, ytrain)

clfl1 = LinearSVC(penalty='l1', dual=False)
clfl1.fit(xtrain, ytrain)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l1', random_state=None, tol=0.0001,
#           verbose=0)

# %%
plot_svm_groups(x, y, clfl2)
plot_svm_groups(x, y, clfl1)

# %%
x[0].reshape(1, 2)
# Out:
# array([[ 2.01194369, -7.71923724]])

# %%
point = [[3.4, 10.2]]
y_ = clfl1.decision_function(point)
w_norm = np.linalg.norm(clf.coef_)
dist = y_ / w_norm
print(dist)

y_ = clfl2.decision_function(point)
w_norm = np.linalg.norm(clf.coef_)
dist = y_ / w_norm
print(dist)
# Out:
# [11.37475821]
# [11.15633434]

# %%
clfl1.predict(point), clfl2.predict(point)
# Out:
# (array([1]), array([1]))

# %%
clf = LinearSVC(C=.01)
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       192
#            1       0.84      0.83      0.83       183
#
#     accuracy                           0.84       375
#    macro avg       0.84      0.84      0.84       375
# weighted avg       0.84      0.84      0.84       375
#
# Train Accuracy: 0.84
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85        58
#            1       0.87      0.88      0.87        67
#
#     accuracy                           0.86       125
#    macro avg       0.86      0.86      0.86       125
# weighted avg       0.86      0.86      0.86       125
#
# Test Accuracy: 0.864

# %%
clf = SVC(kernel='sigmoid')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78       192
#            1       0.77      0.75      0.76       183
#
#     accuracy                           0.77       375
#    macro avg       0.77      0.77      0.77       375
# weighted avg       0.77      0.77      0.77       375
#
# Train Accuracy: 0.768
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        58
#            1       0.87      0.82      0.85        67
#
#     accuracy                           0.84       125
#    macro avg       0.84      0.84      0.84       125
# weighted avg       0.84      0.84      0.84       125
#
# Test Accuracy: 0.84

# %%
clf = SVC(kernel='poly', degree=3)
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.71      0.80       192
#            1       0.76      0.95      0.84       183
#
#     accuracy                           0.82       375
#    macro avg       0.84      0.83      0.82       375
# weighted avg       0.85      0.82      0.82       375
#
# Train Accuracy: 0.824
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78        58
#            1       0.77      0.96      0.85        67
#
#     accuracy                           0.82       125
#    macro avg       0.85      0.81      0.82       125
# weighted avg       0.84      0.82      0.82       125
#
# Test Accuracy: 0.824

# %% [markdown]
# ### let's look at RBF (Radial Basis Function)
# - most popular svm
# - project your data into a higher dimension and separate it there

# %%
clf = SVC(kernel='rbf')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       192
#            1       0.85      0.84      0.84       183
#
#     accuracy                           0.85       375
#    macro avg       0.85      0.85      0.85       375
# weighted avg       0.85      0.85      0.85       375
#
# Train Accuracy: 0.848
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        58
#            1       0.88      0.90      0.89        67
#
#     accuracy                           0.88       125
#    macro avg       0.88      0.88      0.88       125
# weighted avg       0.88      0.88      0.88       125
#
# Test Accuracy: 0.88

# %%
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)

# %%
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       192
#            1       0.85      0.84      0.84       183
#
#     accuracy                           0.85       375
#    macro avg       0.85      0.85      0.85       375
# weighted avg       0.85      0.85      0.85       375
#
# Train Accuracy: 0.848
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        58
#            1       0.88      0.90      0.89        67
#
#     accuracy                           0.88       125
#    macro avg       0.88      0.88      0.88       125
# weighted avg       0.88      0.88      0.88       125
#
# Test Accuracy: 0.88

# %%
print(clf.coef_)
clf.decision_function([[-1, 0]])
# Out:
# [[ 0.19320401 -0.05268438]]
# array([-0.27206569])

# %% [markdown]
# ### Thoughts
#
# - Training data is probably coming from the overlaps
# - Testing data is probably from the outside of each group

# %% [markdown]
# ## RBF SVM
# ![](images/svm-euc.png)

# %%
x, y = make_circles(n_samples=2000, shuffle=True, noise=0.05)

# %%
plot_groups(x, y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y)

# %% [markdown]
# ### Linear SVM

# %%
clf = LinearSVC()
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.51      0.57      0.54       754
#            1       0.50      0.44      0.47       746
#
#     accuracy                           0.50      1500
#    macro avg       0.50      0.50      0.50      1500
# weighted avg       0.50      0.50      0.50      1500
#
# Train Accuracy: 0.5046666666666667
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.45      0.51      0.48       246
#            1       0.45      0.40      0.42       254
#
#     accuracy                           0.45       500
#    macro avg       0.45      0.45      0.45       500
# weighted avg       0.45      0.45      0.45       500
#
# Test Accuracy: 0.452

# %% [markdown]
# ### RBF

# %%
clf = SVC(kernel='rbf')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       754
#            1       0.98      0.98      0.98       746
#
#     accuracy                           0.98      1500
#    macro avg       0.98      0.98      0.98      1500
# weighted avg       0.98      0.98      0.98      1500
#
# Train Accuracy: 0.9793333333333333
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       246
#            1       0.98      0.98      0.98       254
#
#     accuracy                           0.98       500
#    macro avg       0.98      0.98      0.98       500
# weighted avg       0.98      0.98      0.98       500
#
# Test Accuracy: 0.982

# %% [markdown]
# ### Thoughts
# - When do use this?
# - When the boundary isn't linear, when you cannot separate the data in the current dimensions.

# %% [markdown]
# ## Sigmoidal SVM

# %%
x, y = make_moons(n_samples=2000, noise=0.10)

# %%
plot_groups(x, y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y)

# %%
clf = SVC(kernel='sigmoid')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.64       752
#            1       0.63      0.63      0.63       748
#
#     accuracy                           0.63      1500
#    macro avg       0.63      0.63      0.63      1500
# weighted avg       0.63      0.63      0.63      1500
#
# Train Accuracy: 0.634
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.65       248
#            1       0.66      0.68      0.67       252
#
#     accuracy                           0.66       500
#    macro avg       0.66      0.66      0.66       500
# weighted avg       0.66      0.66      0.66       500
#
# Test Accuracy: 0.662

# %% [markdown]
# ### RBF

# %%
clf = SVC(kernel='rbf')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       752
#            1       1.00      1.00      1.00       748
#
#     accuracy                           1.00      1500
#    macro avg       1.00      1.00      1.00      1500
# weighted avg       1.00      1.00      1.00      1500
#
# Train Accuracy: 1.0
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       248
#            1       1.00      1.00      1.00       252
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# Test Accuracy: 0.998

# %% [markdown]
# ### Linear

# %%
clf = LinearSVC()
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       752
#            1       0.89      0.89      0.89       748
#
#     accuracy                           0.89      1500
#    macro avg       0.89      0.89      0.89      1500
# weighted avg       0.89      0.89      0.89      1500
#
# Train Accuracy: 0.8866666666666667
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       248
#            1       0.88      0.86      0.87       252
#
#     accuracy                           0.87       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.87      0.87      0.87       500
#
# Test Accuracy: 0.868

# %% [markdown]
# ## Polynomial SVM

# %%
clf = SVC(kernel='poly', degree=3, gamma='auto')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93       752
#            1       0.89      0.99      0.94       748
#
#     accuracy                           0.93      1500
#    macro avg       0.94      0.93      0.93      1500
# weighted avg       0.94      0.93      0.93      1500
#
# Train Accuracy: 0.9346666666666666
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.92       248
#            1       0.88      0.99      0.93       252
#
#     accuracy                           0.93       500
#    macro avg       0.94      0.93      0.93       500
# weighted avg       0.94      0.93      0.93       500
#
# Test Accuracy: 0.93

# %% [markdown]
# ###  Thoughts?

# %%
x, y = make_blobs(n_samples=3000, n_features=2, centers=3, cluster_std=1.8)
plot_groups3(x, y)

# %% [markdown]
# ## Let's try all types of SVMs

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y)

# %% [markdown]
# ### Linear

# %%
clf = SVC(kernel='linear')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       743
#            1       1.00      1.00      1.00       769
#            2       1.00      1.00      1.00       738
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250
#
# Train Accuracy: 1.0
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       257
#            1       1.00      1.00      1.00       231
#            2       1.00      1.00      1.00       262
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Test Accuracy: 1.0

# %% [markdown]
# ### Polynomial (3)

# %%
clf = SVC(kernel='poly', degree=3)
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       743
#            1       1.00      0.99      1.00       769
#            2       1.00      1.00      1.00       738
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250
#
# Train Accuracy: 0.9973333333333333
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       257
#            1       1.00      0.99      1.00       231
#            2       1.00      1.00      1.00       262
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Test Accuracy: 0.996

# %% [markdown]
# ### RBF

# %%
clf = SVC(kernel='rbf')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       743
#            1       1.00      1.00      1.00       769
#            2       1.00      1.00      1.00       738
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250
#
# Train Accuracy: 1.0
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       257
#            1       1.00      1.00      1.00       231
#            2       1.00      1.00      1.00       262
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Test Accuracy: 1.0

# %% [markdown]
# ### Sigmoidal

# %%
clf = SVC(kernel='sigmoid')
clf.fit(xtrain, ytrain)
ytrain_pred = clf.predict(xtrain)
ytest_pred = clf.predict(xtest)
plot_svm_groups(x, y, clf)
print_report(ytrain, ytest, ytrain_pred, ytest_pred)
# Out:
# Train Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       743
#            1       1.00      1.00      1.00       769
#            2       1.00      1.00      1.00       738
#
#     accuracy                           1.00      2250
#    macro avg       1.00      1.00      1.00      2250
# weighted avg       1.00      1.00      1.00      2250
#
# Train Accuracy: 1.0
# Test Scores
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       257
#            1       1.00      1.00      1.00       231
#            2       1.00      1.00      1.00       262
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Test Accuracy: 1.0

# %% [markdown]
# ### Assessment

# %%
ys = clf.decision_function(xtest)
ys
# Out:
# array([[ 0.73102529,  2.30383866, -0.28653108],
#        [ 2.30341254,  0.70834915, -0.25288722],
#        [ 2.30450877,  0.7158681 , -0.27575627],
#        ...,
#        [ 0.70848425,  2.30681293, -0.27378623],
#        [ 0.72879714,  2.3035451 , -0.28449362],
#        [ 1.25610194, -0.30221923,  2.28827137]])

# %%
w_norm = np.linalg.norm(clf.coef_)
dist = ys / w_norm
dist
# Out:
# array([[ 0.52323079,  1.64897075, -0.2050844 ],
#        [ 1.64866576,  0.50700036, -0.18100383],
#        [ 1.64945038,  0.51238204, -0.19737234],
#        ...,
#        [ 0.50709705,  1.65109958, -0.19596228],
#        [ 0.521636  ,  1.64876064, -0.20362609],
#        [ 0.899054  , -0.21631318,  1.63782848]])

# %%
dist_abs = np.abs(dist)
dist_abs
# Out:
# array([[0.52323079, 1.64897075, 0.2050844 ],
#        [1.64866576, 0.50700036, 0.18100383],
#        [1.64945038, 0.51238204, 0.19737234],
#        ...,
#        [0.50709705, 1.65109958, 0.19596228],
#        [0.521636  , 1.64876064, 0.20362609],
#        [0.899054  , 0.21631318, 1.63782848]])

# %%
dist_abs[np.where(clf.predict(xtest)==2)]
# Out:
# array([[0.90823123, 0.21851248, 1.63914486],
#        [0.91547984, 0.21665102, 1.62849869],
#        [0.91180275, 0.21055004, 1.60892154],
#        [0.91443315, 0.22175442, 1.64414165],
#        [0.91305958, 0.22287464, 1.64715754],
#        [0.56934887, 0.20000166, 1.63938393],
#        [0.67464541, 0.20817745, 1.64046161],
#        [0.87524152, 0.21920638, 1.64690984],
#        [0.85371032, 0.2097997 , 1.63559344],
#        [0.903223  , 0.21067712, 1.62120605],
#        [0.88957994, 0.21459088, 1.63721726],
#        [0.91846923, 0.22242192, 1.6438928 ],
#        [0.90089275, 0.21676985, 1.63815554],
#        [0.90132675, 0.21683693, 1.6381435 ],
#        [0.87905728, 0.2203309 , 1.64819721],
#        [0.89667208, 0.21673586, 1.63942631],
#        [0.92570874, 0.2227678 , 1.63929827],
#        [0.92889941, 0.22285667, 1.63494397],
#        [0.92332067, 0.22462737, 1.64714616],
#        [0.90212506, 0.21654791, 1.63720733],
#        [0.8499581 , 0.21968817, 1.64904433],
#        [0.91897388, 0.22175387, 1.64177707],
#        [0.92620049, 0.21695348, 1.60286557],
#        [0.90308048, 0.21645709, 1.63660945],
#        [0.86736495, 0.21580356, 1.64275311],
#        [0.90343974, 0.2229024 , 1.64938401],
#        [0.64244487, 0.2111756 , 1.64400278],
#        [0.90160905, 0.21697212, 1.63833277],
#        [0.88322471, 0.21547169, 1.64013867],
#        [0.89588455, 0.21305902, 1.63200204],
#        [0.81844481, 0.21566542, 1.64536996],
#        [0.90740904, 0.22181982, 1.6465711 ],
#        [0.88499518, 0.21109524, 1.63183894],
#        [0.85748212, 0.21742992, 1.64577457],
#        [0.89907971, 0.21981379, 1.6446823 ],
#        [0.56592086, 0.19857889, 1.63890265],
#        [0.92812601, 0.22172318, 1.63062602],
#        [0.88752681, 0.21936528, 1.64584364],
#        [0.89459037, 0.21316041, 1.63275101],
#        [0.89775426, 0.2178126 , 1.64123149],
#        [0.91496161, 0.21917577, 1.6370987 ],
#        [0.88939418, 0.21415276, 1.6364397 ],
#        [0.91434989, 0.21711976, 1.63127906],
#        [0.85192866, 0.21067967, 1.63703904],
#        [0.92618874, 0.22383181, 1.64264676],
#        [0.92541051, 0.22342566, 1.64198355],
#        [0.92431402, 0.22313271, 1.64199306],
#        [0.89639846, 0.21974058, 1.64508271],
#        [0.88488423, 0.21135534, 1.63237333],
#        [0.90162673, 0.2175942 , 1.63965159],
#        [0.83574288, 0.20988855, 1.63741121],
#        [0.92072781, 0.22080627, 1.63749399],
#        [0.80484391, 0.20803747, 1.6370126 ],
#        [0.91865642, 0.22182   , 1.64216121],
#        [0.91582694, 0.22250035, 1.64532878],
#        [0.91139688, 0.21796565, 1.63607172],
#        [0.927674  , 0.2236997 , 1.64055575],
#        [0.91534283, 0.21764378, 1.63205955],
#        [0.91220431, 0.22013551, 1.64123143],
#        [0.59843984, 0.21440449, 1.64806156],
#        [0.9057769 , 0.21446772, 1.63018327],
#        [0.86897436, 0.21532348, 1.64188795],
#        [0.90756825, 0.21991258, 1.64258477],
#        [0.91701744, 0.22191095, 1.64332412],
#        [0.9161804 , 0.221682  , 1.64316236],
#        [0.92206211, 0.21831783, 1.62573292],
#        [0.93000237, 0.22260897, 1.63115755],
#        [0.88482349, 0.21912129, 1.64580232],
#        [0.90042247, 0.21619195, 1.63708094],
#        [0.61355492, 0.21584003, 1.64885465],
#        [0.90849872, 0.21635207, 1.6335259 ],
#        [0.85906167, 0.21711152, 1.64524807],
#        [0.89265008, 0.21692928, 1.64080801],
#        [0.88983165, 0.2149476 , 1.63782034],
#        [0.92017944, 0.21518266, 1.61341011],
#        [0.88320248, 0.21919734, 1.64611046],
#        [0.92468703, 0.22136298, 1.63503182],
#        [0.92990327, 0.2259448 , 1.64648619],
#        [0.59003056, 0.20768334, 1.64307751],
#        [0.90646244, 0.22214199, 1.64741848],
#        [0.91145554, 0.22063397, 1.64274558],
#        [0.90164917, 0.21945792, 1.64341285],
#        [0.92861103, 0.22491331, 1.6440854 ],
#        [0.92519161, 0.2232403 , 1.64155283],
#        [0.8928476 , 0.21657552, 1.64011103],
#        [0.90986537, 0.21897963, 1.6395138 ],
#        [0.88314408, 0.20960781, 1.62952401],
#        [0.92424824, 0.2200028 , 1.62971294],
#        [0.90957327, 0.21836437, 1.63814153],
#        [0.91402504, 0.22297369, 1.64706445],
#        [0.91608573, 0.22045891, 1.6399794 ],
#        [0.892256  , 0.21455347, 1.63640872],
#        [0.90449478, 0.21913973, 1.64195822],
#        [0.89295842, 0.20551199, 1.61494177],
#        [0.85708038, 0.20593587, 1.62933064],
#        [0.91975566, 0.22067205, 1.63792893],
#        [0.84853422, 0.20695223, 1.63213685],
#        [0.91043917, 0.21810976, 1.63702683],
#        [0.92021127, 0.22410647, 1.64733408],
#        [0.902715  , 0.21753755, 1.63915443],
#        [0.91542339, 0.21753443, 1.63161905],
#        [0.89996409, 0.21772835, 1.64045109],
#        [0.91804423, 0.22016985, 1.63776399],
#        [0.91413889, 0.22045806, 1.64108265],
#        [0.88527918, 0.21292047, 1.63521041],
#        [0.89572335, 0.219166  , 1.64419507],
#        [0.90201108, 0.22177854, 1.64765321],
#        [0.87680115, 0.20969814, 1.63149161],
#        [0.90830427, 0.2150581 , 1.63003915],
#        [0.78433068, 0.19577989, 1.62393876],
#        [0.90064875, 0.2191649 , 1.64309963],
#        [0.89602597, 0.21790462, 1.64183306],
#        [0.91204992, 0.21113611, 1.6111707 ],
#        [0.86336201, 0.21874593, 1.64715064],
#        [0.89594719, 0.21739037, 1.6408843 ],
#        [0.92285342, 0.22461775, 1.64736976],
#        [0.75960824, 0.2013442 , 1.63148581],
#        [0.91764364, 0.22321144, 1.64626631],
#        [0.89213108, 0.21985212, 1.64598639],
#        [0.8047227 , 0.21377979, 1.64364372],
#        [0.87898937, 0.21934926, 1.64677724],
#        [0.87288189, 0.21029999, 1.63341231],
#        [0.92163703, 0.22155082, 1.6391391 ],
#        [0.91729344, 0.22199704, 1.6434038 ],
#        [0.88608717, 0.21851302, 1.64467751],
#        [0.87052655, 0.20971696, 1.63290924],
#        [0.92156032, 0.22342119, 1.64484965],
#        [0.89045652, 0.2187552 , 1.64442082],
#        [0.92481082, 0.22388933, 1.64402219],
#        [0.92480524, 0.22528328, 1.64810995],
#        [0.90293168, 0.21492222, 1.63304492],
#        [0.91641295, 0.21686111, 1.62816339],
#        [0.87103148, 0.20964414, 1.63268753],
#        [0.91443751, 0.21990491, 1.63946672],
#        [0.80925331, 0.21738279, 1.64759336],
#        [0.9063278 , 0.21983053, 1.64282328],
#        [0.90650404, 0.22081484, 1.64480571],
#        [0.89791753, 0.21847911, 1.64246256],
#        [0.81547073, 0.21165667, 1.64078031],
#        [0.81853021, 0.21765769, 1.64766836],
#        [0.8574349 , 0.21370204, 1.64072372],
#        [0.90377953, 0.2169411 , 1.63741953],
#        [0.92346601, 0.22233298, 1.64008008],
#        [0.91755128, 0.22097614, 1.6404951 ],
#        [0.91920939, 0.22032307, 1.63727794],
#        [0.88869189, 0.21173078, 1.6319102 ],
#        [0.90257344, 0.21662288, 1.63719545],
#        [0.92956239, 0.22561307, 1.64564411],
#        [0.91701722, 0.2226523 , 1.64518374],
#        [0.85128367, 0.20987455, 1.63597526],
#        [0.92198679, 0.22056358, 1.63532394],
#        [0.87617168, 0.21771308, 1.64464462],
#        [0.54606137, 0.20621933, 1.64582274],
#        [0.86217223, 0.2210551 , 1.65023727],
#        [0.55045431, 0.1835923 , 1.63389977],
#        [0.90891356, 0.21691581, 1.63477909],
#        [0.8701058 , 0.21071521, 1.63462342],
#        [0.81416472, 0.20996659, 1.63883348],
#        [0.92613837, 0.22466688, 1.64543979],
#        [0.92033947, 0.22363344, 1.6460804 ],
#        [0.91267567, 0.22200454, 1.64539299],
#        [0.9102338 , 0.22278063, 1.64775824],
#        [0.919151  , 0.21970485, 1.63528478],
#        [0.92948023, 0.22465324, 1.64210299],
#        [0.91355016, 0.21745615, 1.63304977],
#        [0.8852558 , 0.21081189, 1.63120621],
#        [0.87425015, 0.21882657, 1.64645232],
#        [0.91823075, 0.22263356, 1.64456457],
#        [0.90563016, 0.21924559, 1.64181016],
#        [0.91955509, 0.22306125, 1.64499523],
#        [0.90785291, 0.22021095, 1.64313229],
#        [0.91354801, 0.219528  , 1.63897891],
#        [0.78130358, 0.2151404 , 1.64573244],
#        [0.84334438, 0.21402927, 1.64223283],
#        [0.89644908, 0.2174499 , 1.64087099],
#        [0.92082316, 0.22076387, 1.63726026],
#        [0.90935972, 0.21902379, 1.63985385],
#        [0.91348872, 0.22250224, 1.64621154],
#        [0.89641763, 0.21438886, 1.63469186],
#        [0.90233113, 0.22140651, 1.64692263],
#        [0.89020109, 0.21143489, 1.63076295],
#        [0.89821966, 0.21763978, 1.64077157],
#        [0.90789459, 0.21959631, 1.64177333],
#        [0.89494854, 0.21911138, 1.64424735],
#        [0.92233953, 0.22331613, 1.64406382],
#        [0.89633826, 0.21418559, 1.63428555],
#        [0.89273897, 0.21895971, 1.64438486],
#        [0.90826658, 0.22058962, 1.64380659],
#        [0.90310393, 0.21454488, 1.63201739],
#        [0.87995775, 0.21839094, 1.64524927],
#        [0.82337278, 0.21416851, 1.64342526],
#        [0.8983252 , 0.21954364, 1.64434755],
#        [0.8707036 , 0.21489832, 1.64105822],
#        [0.90284673, 0.22069019, 1.6454853 ],
#        [0.88900193, 0.21381715, 1.63590828],
#        [0.87383112, 0.2157359 , 1.64194291],
#        [0.90514385, 0.22089078, 1.64531878],
#        [0.90518255, 0.2211555 , 1.64582486],
#        [0.84173677, 0.21125989, 1.63874243],
#        [0.87351145, 0.21532937, 1.64136429],
#        [0.88682762, 0.21445617, 1.63764048],
#        [0.89723341, 0.21687571, 1.63954276],
#        [0.91611726, 0.22116752, 1.64186772],
#        [0.93120259, 0.22588044, 1.64488044],
#        [0.58968476, 0.20051595, 1.63778742],
#        [0.83336467, 0.19624252, 1.61891169],
#        [0.91868401, 0.22066704, 1.63878803],
#        [0.91978918, 0.22056556, 1.63755449],
#        [0.91493615, 0.22110205, 1.64231388],
#        [0.90572292, 0.21823726, 1.63956527],
#        [0.90803287, 0.21987748, 1.64234445],
#        [0.90359608, 0.21886659, 1.64167294],
#        [0.92861875, 0.222066  , 1.63138905],
#        [0.91037588, 0.22010062, 1.64194974],
#        [0.91627181, 0.22170524, 1.64317576],
#        [0.88501445, 0.2164159 , 1.64140924],
#        [0.9116109 , 0.22128426, 1.64416901],
#        [0.88830056, 0.21866019, 1.6445978 ],
#        [0.91117153, 0.22255736, 1.6470517 ],
#        [0.78689574, 0.21630221, 1.64687999],
#        [0.90302786, 0.21967912, 1.64348501],
#        [0.90474742, 0.22127682, 1.64616185],
#        [0.91250949, 0.220063  , 1.64090701],
#        [0.8176837 , 0.20616229, 1.63400362],
#        [0.88495191, 0.21831619, 1.64451897],
#        [0.91839326, 0.22138045, 1.64109366],
#        [0.87459045, 0.21579125, 1.6419334 ],
#        [0.91056051, 0.21318181, 1.62180446],
#        [0.84276178, 0.20767191, 1.63382238],
#        [0.92810525, 0.22333572, 1.63848394],
#        [0.90207688, 0.21616866, 1.63637609],
#        [0.83592246, 0.20716595, 1.63381804],
#        [0.90744999, 0.21993828, 1.64268104],
#        [0.81205671, 0.21106183, 1.64022933],
#        [0.91432384, 0.22116885, 1.64277481],
#        [0.90914228, 0.21656647, 1.63369529],
#        [0.8286683 , 0.21150827, 1.63993236],
#        [0.90623694, 0.22042814, 1.64409457],
#        [0.90643148, 0.22077442, 1.64474418],
#        [0.62089755, 0.21632445, 1.64911384],
#        [0.90882438, 0.2201868 , 1.64274124],
#        [0.86906647, 0.21959411, 1.64792114],
#        [0.9202506 , 0.22295208, 1.64432535],
#        [0.58513788, 0.18734711, 1.62941098],
#        [0.90531169, 0.21626798, 1.63512206],
#        [0.89727219, 0.21681691, 1.63941507],
#        [0.91465008, 0.21785644, 1.63336855],
#        [0.91139008, 0.21620966, 1.63101937],
#        [0.85723345, 0.21428177, 1.64154491],
#        [0.91549575, 0.22162674, 1.64335607],
#        [0.85623106, 0.21118018, 1.63728428],
#        [0.91546978, 0.21896485, 1.63610573],
#        [0.62571519, 0.19577685, 1.63147368],
#        [0.9224041 , 0.22041006, 1.6342364 ],
#        [0.91774887, 0.22203213, 1.64325474],
#        [0.7968174 , 0.21521477, 1.64547271],
#        [0.5828455 , 0.21001354, 1.64525131],
#        [0.92527088, 0.22327777, 1.64160639],
#        [0.91932498, 0.22053407, 1.63785538],
#        [0.90565356, 0.22135492, 1.64609675],
#        [0.89327103, 0.21843193, 1.64337171],
#        [0.899054  , 0.21631318, 1.63782848]])
